# %% [markdown]
# ### import librairies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv

# %% [markdown]
# ###### Keras est une bibliothèque de réseaux de neurones écrite en Python qui permet de faciliter la création de modèles de deep learning. Elle est compatible avec les bibliothèques TensorFlow, Theano et Microsoft Cognitive Toolkit (CNTK). Keras offre une interface haut niveau pour construire des réseaux de neurones, avec des fonctionnalités telles que la normalisation des entrées, la régularisation et les méthodes de optimisation. Il est utilisé pour des tâches de classification, de régression et de segmentation d'image.

# %%
from keras.models import Sequential 
#Le modèle séquentiel est une pile linéaire de couches.

# %%
from keras.layers import Dense, SimpleRNN

# %%
def convertToMatrix(data, step):
    X, Y=[], []
    for i in range(len(data)-step):
        d=i+step
        X.append(data[i:d,])
        Y.append(data[d,])
    return np.array(X), np.array(Y)

# %%
step= 2
import warnings
warnings.filterwarnings("ignore")
X = read_csv("DailyDelhiClimateTest.csv",header = 0,index_col=0,parse_dates = True,squeeze=True)
X=X.drop(['humidity','wind_speed','meanpressure'], axis=1)
#remove missing values
X=X.dropna()
df=pd.DataFrame(X)
df.head()
# Out:
#              meantemp
# date
# 2017-01-01  15.913043
# 2017-01-02  18.500000
# 2017-01-03  17.111111
# 2017-01-04  18.700000
# 2017-01-05  18.388889

# %%
plt.plot(df)
plt.show()

# %%
values=df.values
train,test= values[0:90,:], values[90:114,:]

#add step elements into train and test
test= np.append(test, np.repeat(test[-1,], step))
train=np.append(train, np.repeat(train[-1,], step))

trainX, trainY=convertToMatrix(train, step)
testX, testY=convertToMatrix(test, step)

trainX=np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX=np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# C’est notamment le cas dans la librairie Keras que nous utilisons. Le code ci-dessous permet de définir un modèle simple à 3 couches RNN, où R=11, qui prend en entrée des séquences de taille T=1 caractère, chacun encodé comme un vecteur de taille M= step.

# %%
model= Sequential()
model.add(SimpleRNN(units=11, input_shape=(1,step), activation="relu"))
model.add(Dense(11, activation= "relu"))
model.add(Dense(1))
model.compile(loss= 'mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_6 (SimpleRNN)    (None, 11)                154
#
#  dense_12 (Dense)            (None, 11)                132
#
#  dense_13 (Dense)            (None, 1)                 12
#
# =================================================================
# Total params: 298
# Trainable params: 298
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# On voit alors que notre modèle a 298 paramètres (ou poids) à apprendre.

# %%
model.fit(trainX, trainY, epochs=100, batch_size=16, verbose=2)
trainPredict=model.predict(trainX)
testPredict=model.predict(testX)
predicted=np.concatenate((trainPredict, testPredict),axis=0)

trainScore=model.evaluate(trainX, trainY, verbose=0)
print(trainScore)
# Out:
# Epoch 1/100
# 6/6 - 3s - loss: 413.2237 - 3s/epoch - 429ms/step
# Epoch 2/100
# 6/6 - 0s - loss: 390.5136 - 25ms/epoch - 4ms/step
# Epoch 3/100
# 6/6 - 0s - loss: 368.2307 - 49ms/epoch - 8ms/step
# Epoch 4/100
# 6/6 - 0s - loss: 346.4403 - 33ms/epoch - 5ms/step
# Epoch 5/100
# 6/6 - 0s - loss: 324.3119 - 34ms/epoch - 6ms/step
# Epoch 6/100
# 6/6 - 0s - loss: 301.5392 - 35ms/epoch - 6ms/step
# Epoch 7/100
# 6/6 - 0s - loss: 279.5128 - 35ms/epoch - 6ms/step
# Epoch 8/100
# 6/6 - 0s - loss: 256.1578 - 39ms/epoch - 6ms/step
# Epoch 9/100
# 6/6 - 0s - loss: 231.9792 - 35ms/epoch - 6ms/step
# Epoch 10/100
# 6/6 - 0s - loss: 209.0482 - 39ms/epoch - 6ms/step
# Epoch 11/100
# 6/6 - 0s - loss: 185.7373 - 42ms/epoch - 7ms/step
# Epoch 12/100
# 6/6 - 0s - loss: 164.4985 - 38ms/epoch - 6ms/step
# Epoch 13/100
# 6/6 - 0s - loss: 146.0153 - 35ms/epoch - 6ms/step
# Epoch 14/100
# 6/6 - 0s - loss: 126.8294 - 39ms/epoch - 6ms/step
# Epoch 15/100
# 6/6 - 0s - loss: 110.3809 - 30ms/epoch - 5ms/step
# Epoch 16/100
# 6/6 - 0s - loss: 93.9943 - 36ms/epoch - 6ms/step
# Epoch 17/100
# 6/6 - 0s - loss: 79.1655 - 34ms/epoch - 6ms/step
# Epoch 18/100
# 6/6 - 0s - loss: 65.5530 - 30ms/epoch - 5ms/step
# Epoch 19/100
# 6/6 - 0s - loss: 53.9172 - 31ms/epoch - 5ms/step
# Epoch 20/100
# 6/6 - 0s - loss: 43.2310 - 36ms/epoch - 6ms/step
# Epoch 21/100
# 6/6 - 0s - loss: 34.3669 - 32ms/epoch - 5ms/step
# Epoch 22/100
# 6/6 - 0s - loss: 26.9005 - 37ms/epoch - 6ms/step
# Epoch 23/100
# 6/6 - 0s - loss: 20.5979 - 37ms/epoch - 6ms/step
# Epoch 24/100
# 6/6 - 0s - loss: 15.6169 - 39ms/epoch - 6ms/step
# Epoch 25/100
# 6/6 - 0s - loss: 12.0017 - 32ms/epoch - 5ms/step
# Epoch 26/100
# 6/6 - 0s - loss: 9.2073 - 35ms/epoch - 6ms/step
# Epoch 27/100
# 6/6 - 0s - loss: 7.1485 - 33ms/epoch - 5ms/step
# Epoch 28/100
# 6/6 - 0s - loss: 5.6222 - 35ms/epoch - 6ms/step
# Epoch 29/100
# 6/6 - 0s - loss: 4.7585 - 32ms/epoch - 5ms/step
# Epoch 30/100
# 6/6 - 0s - loss: 4.2406 - 34ms/epoch - 6ms/step
# Epoch 31/100
# 6/6 - 0s - loss: 3.8467 - 33ms/epoch - 5ms/step
# Epoch 32/100
# 6/6 - 0s - loss: 3.6255 - 35ms/epoch - 6ms/step
# Epoch 33/100
# 6/6 - 0s - loss: 3.5692 - 36ms/epoch - 6ms/step
# Epoch 34/100
# 6/6 - 0s - loss: 3.5127 - 27ms/epoch - 5ms/step
# Epoch 35/100
# 6/6 - 0s - loss: 3.4833 - 30ms/epoch - 5ms/step
# Epoch 36/100
# 6/6 - 0s - loss: 3.4812 - 38ms/epoch - 6ms/step
# Epoch 37/100
# 6/6 - 0s - loss: 3.4737 - 28ms/epoch - 5ms/step
# Epoch 38/100
# 6/6 - 0s - loss: 3.4753 - 44ms/epoch - 7ms/step
# Epoch 39/100
# 6/6 - 0s - loss: 3.4732 - 32ms/epoch - 5ms/step
# Epoch 40/100
# 6/6 - 0s - loss: 3.4754 - 33ms/epoch - 5ms/step
# Epoch 41/100
# 6/6 - 0s - loss: 3.4738 - 34ms/epoch - 6ms/step
# Epoch 42/100
# 6/6 - 0s - loss: 3.4739 - 35ms/epoch - 6ms/step
# Epoch 43/100
# 6/6 - 0s - loss: 3.4761 - 32ms/epoch - 5ms/step
# Epoch 44/100
# 6/6 - 0s - loss: 3.4734 - 37ms/epoch - 6ms/step
# Epoch 45/100
# 6/6 - 0s - loss: 3.4724 - 33ms/epoch - 5ms/step
# Epoch 46/100
# 6/6 - 0s - loss: 3.4728 - 29ms/epoch - 5ms/step
# Epoch 47/100
# 6/6 - 0s - loss: 3.4754 - 33ms/epoch - 5ms/step
# Epoch 48/100
# 6/6 - 0s - loss: 3.4724 - 35ms/epoch - 6ms/step
# Epoch 49/100
# 6/6 - 0s - loss: 3.4734 - 27ms/epoch - 4ms/step
# Epoch 50/100
# 6/6 - 0s - loss: 3.4718 - 34ms/epoch - 6ms/step
# Epoch 51/100
# 6/6 - 0s - loss: 3.4724 - 35ms/epoch - 6ms/step
# Epoch 52/100
# 6/6 - 0s - loss: 3.4708 - 34ms/epoch - 6ms/step
# Epoch 53/100
# 6/6 - 0s - loss: 3.4721 - 31ms/epoch - 5ms/step
# Epoch 54/100
# 6/6 - 0s - loss: 3.4728 - 38ms/epoch - 6ms/step
# Epoch 55/100
# 6/6 - 0s - loss: 3.4753 - 30ms/epoch - 5ms/step
# Epoch 56/100
# 6/6 - 0s - loss: 3.4706 - 31ms/epoch - 5ms/step
# Epoch 57/100
# 6/6 - 0s - loss: 3.4710 - 32ms/epoch - 5ms/step
# Epoch 58/100
# 6/6 - 0s - loss: 3.4705 - 38ms/epoch - 6ms/step
# Epoch 59/100
# 6/6 - 0s - loss: 3.4695 - 33ms/epoch - 5ms/step
# Epoch 60/100
# 6/6 - 0s - loss: 3.4704 - 34ms/epoch - 6ms/step
# Epoch 61/100
# 6/6 - 0s - loss: 3.4719 - 26ms/epoch - 4ms/step
# Epoch 62/100
# 6/6 - 0s - loss: 3.4693 - 34ms/epoch - 6ms/step
# Epoch 63/100
# 6/6 - 0s - loss: 3.4706 - 29ms/epoch - 5ms/step
# Epoch 64/100
# 6/6 - 0s - loss: 3.4696 - 35ms/epoch - 6ms/step
# Epoch 65/100
# 6/6 - 0s - loss: 3.4685 - 39ms/epoch - 6ms/step
# Epoch 66/100
# 6/6 - 0s - loss: 3.4683 - 33ms/epoch - 5ms/step
# Epoch 67/100
# 6/6 - 0s - loss: 3.4693 - 31ms/epoch - 5ms/step
# Epoch 68/100
# 6/6 - 0s - loss: 3.4681 - 33ms/epoch - 5ms/step
# Epoch 69/100
# 6/6 - 0s - loss: 3.4690 - 36ms/epoch - 6ms/step
# Epoch 70/100
# 6/6 - 0s - loss: 3.4680 - 45ms/epoch - 7ms/step
# Epoch 71/100
# 6/6 - 0s - loss: 3.4683 - 38ms/epoch - 6ms/step
# Epoch 72/100
# 6/6 - 0s - loss: 3.4678 - 31ms/epoch - 5ms/step
# Epoch 73/100
# 6/6 - 0s - loss: 3.4688 - 39ms/epoch - 6ms/step
# Epoch 74/100
# 6/6 - 0s - loss: 3.4673 - 31ms/epoch - 5ms/step
# Epoch 75/100
# 6/6 - 0s - loss: 3.4666 - 33ms/epoch - 5ms/step
# Epoch 76/100
# 6/6 - 0s - loss: 3.4666 - 36ms/epoch - 6ms/step
# Epoch 77/100
# 6/6 - 0s - loss: 3.4718 - 30ms/epoch - 5ms/step
# Epoch 78/100
# 6/6 - 0s - loss: 3.4662 - 34ms/epoch - 6ms/step
# Epoch 79/100
# 6/6 - 0s - loss: 3.4655 - 37ms/epoch - 6ms/step
# Epoch 80/100
# 6/6 - 0s - loss: 3.4687 - 32ms/epoch - 5ms/step
# Epoch 81/100
# 6/6 - 0s - loss: 3.4710 - 42ms/epoch - 7ms/step
# Epoch 82/100
# 6/6 - 0s - loss: 3.4665 - 37ms/epoch - 6ms/step
# Epoch 83/100
# 6/6 - 0s - loss: 3.4664 - 30ms/epoch - 5ms/step
# Epoch 84/100
# 6/6 - 0s - loss: 3.4654 - 33ms/epoch - 5ms/step
# Epoch 85/100
# 6/6 - 0s - loss: 3.4633 - 32ms/epoch - 5ms/step
# Epoch 86/100
# 6/6 - 0s - loss: 3.4637 - 36ms/epoch - 6ms/step
# Epoch 87/100
# 6/6 - 0s - loss: 3.4643 - 38ms/epoch - 6ms/step
# Epoch 88/100
# 6/6 - 0s - loss: 3.4667 - 59ms/epoch - 10ms/step
# Epoch 89/100
# 6/6 - 0s - loss: 3.4630 - 39ms/epoch - 6ms/step
# Epoch 90/100
# 6/6 - 0s - loss: 3.4638 - 36ms/epoch - 6ms/step
# Epoch 91/100
# 6/6 - 0s - loss: 3.4635 - 36ms/epoch - 6ms/step
# Epoch 92/100
# 6/6 - 0s - loss: 3.4623 - 37ms/epoch - 6ms/step
# Epoch 93/100
# 6/6 - 0s - loss: 3.4677 - 35ms/epoch - 6ms/step
# Epoch 94/100
# 6/6 - 0s - loss: 3.4649 - 39ms/epoch - 6ms/step
# Epoch 95/100
# 6/6 - 0s - loss: 3.4634 - 35ms/epoch - 6ms/step
# Epoch 96/100
# 6/6 - 0s - loss: 3.4631 - 35ms/epoch - 6ms/step
# Epoch 97/100
# 6/6 - 0s - loss: 3.4617 - 36ms/epoch - 6ms/step
# Epoch 98/100
# 6/6 - 0s - loss: 3.4624 - 28ms/epoch - 5ms/step
# Epoch 99/100
# 6/6 - 0s - loss: 3.4611 - 30ms/epoch - 5ms/step
# Epoch 100/100
# 6/6 - 0s - loss: 3.4609 - 30ms/epoch - 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 222ms/step
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x000001C36D830820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3.4589970111846924

# %%
index= df.index.values
plt.plot(index,df)
plt.plot(index,predicted)
plt.axvline(df.index[90], c="r")
plt.show()

# %%
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
rmse=sqrt(mean_squared_error(df,predicted))
print(rmse)
# Out:
# 0.8140200697120633
